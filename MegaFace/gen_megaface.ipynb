# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os

from easydict import EasyDict as edict
import time
import sys
import numpy as np
import argparse
import struct
import cv2
import sklearn
from sklearn.preprocessing import normalize

# %%
import tensorflow as tf
from tensorflow import keras
import os

def read_img(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_COLOR)
    print(type(img))
    img = (img / 255 - 0.5) / 0.5
    return img


def get_feature(imgs, model):
    count = len(imgs)
    data = np.zeros(shape=(count, *imgs[0].shape))

    for idx, img in enumerate(imgs):
        img = img[:, :, ::-1]  #to rgb
        data[idx] = img
    
    F = model.predict(data)
    F = sklearn.preprocessing.normalize(F)
    #print('F', F.shape)
    return F


def write_bin(path, feature):
    feature = list(feature)
    with open(path, 'wb') as f:
        f.write(struct.pack('4i', len(feature), 1, 4, 5))
        f.write(struct.pack("%df" % len(feature), *feature))


def get_and_write(buffer, model):
    imgs = []
    for k in buffer:
        imgs.append(k[0])
    features = get_feature(imgs, model)
    #print(np.linalg.norm(feature))
    assert features.shape[0] == len(buffer)
    for ik, k in enumerate(buffer):
        out_path = k[1]
        feature = features[ik].flatten()
        write_bin(out_path, feature)

# %%
batch_size = 8
image_size = '3,112,112'
# gpu = -1
nomf = False
algo = 'insightface'
megaface_data = 'data'
facescrub_lst = 'data/facescrub_lst'
megaface_lst = 'data/megaface_lst'
facescrub_root ='data/facescrub_images'
megaface_root ='data/megaface_images'
output = 'feature_out'
facescrub_out = os.path.join(output, 'facescrub')
megaface_out = os.path.join(output, 'megaface')

model = 'GhostFaceNets/GhostFaceNet_W1.3_S1_ArcFace.h5'

# %%
nets = []
image_shape = [int(x) for x in image_size.split(',')]

for model_path in model.split('|'):
    model = keras.models.load_model(model, compile=False)
    # model = backbone.to(ctx)
    # model.eval()
    print(f"LOADED MODEL FROM {model_path}")
    nets.append(model)

# %%
model = nets[0]
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 112, 112, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 20  540         ['input_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 20  80         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 20  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 10  200         ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 10  40         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 112, 112, 10  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 112, 112, 10  90         ['activation_1[0][0]']
#  v2D)                           )
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 10  40         ['depthwise_conv2d[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 112, 112, 10  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 112, 112, 20  0           ['activation_1[0][0]',
#                                 )                                 'activation_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 10  200         ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 10  40         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 112, 112, 10  90         ['batch_normalization_3[0][0]']
#  onv2D)                         )
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 10  40         ['depthwise_conv2d_1[0][0]']
#  rmalization)                   )
#
#  concatenate_1 (Concatenate)    (None, 112, 112, 20  0           ['batch_normalization_3[0][0]',
#                                 )                                 'batch_normalization_4[0][0]']
#
#  add (Add)                      (None, 112, 112, 20  0           ['activation[0][0]',
#                                 )                                 'concatenate_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 32  640         ['add[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 112, 112, 32  288        ['activation_3[0][0]']
#  onv2D)                         )
#
#  batch_normalization_6 (BatchNo  (None, 112, 112, 32  128        ['depthwise_conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 64  0           ['activation_3[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 56, 56, 64)  576         ['concatenate_2[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 64)  256         ['depthwise_conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 16)   1024        ['batch_normalization_7[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 56, 56, 20)  180         ['add[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 20)  80          ['depthwise_conv2d_5[0][0]']
#  ormalization)
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 56, 56, 16)  144         ['batch_normalization_8[0][0]']
#  onv2D)
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 32)   640         ['batch_normalization_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 16)  64          ['depthwise_conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 32)  128         ['conv2d_5[0][0]']
#  ormalization)
#
#  concatenate_3 (Concatenate)    (None, 56, 56, 32)   0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 32)   0           ['batch_normalization_11[0][0]',
#                                                                   'concatenate_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 46)   1472        ['add_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 46)  184         ['conv2d_6[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 56, 56, 46)   0           ['batch_normalization_12[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 56, 56, 46)  414         ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 46)  184         ['depthwise_conv2d_6[0][0]']
#  ormalization)
#
#  activation_6 (Activation)      (None, 56, 56, 46)   0           ['batch_normalization_13[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 56, 56, 92)   0           ['activation_5[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 16)   1472        ['concatenate_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 56, 56, 16)  64          ['conv2d_7[0][0]']
#  ormalization)
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 56, 56, 16)  144         ['batch_normalization_14[0][0]']
#  onv2D)
#
#  batch_normalization_15 (BatchN  (None, 56, 56, 16)  64          ['depthwise_conv2d_7[0][0]']
#  ormalization)
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 32)   0           ['batch_normalization_14[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 32)   0           ['add_1[0][0]',
#                                                                   'concatenate_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 46)   1472        ['add_2[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 56, 56, 46)  184         ['conv2d_8[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 56, 56, 46)   0           ['batch_normalization_16[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 56, 56, 46)  414         ['activation_7[0][0]']
#  onv2D)
#
#  batch_normalization_17 (BatchN  (None, 56, 56, 46)  184         ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 56, 56, 46)   0           ['batch_normalization_17[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 56, 56, 92)   0           ['activation_7[0][0]',
#                                                                   'activation_8[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 28, 28, 92)  2300        ['concatenate_6[0][0]']
#  onv2D)
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 92)  368         ['depthwise_conv2d_9[0][0]']
#  ormalization)
#
#  global_average_pooling2d (Glob  (None, 92)          0           ['batch_normalization_18[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 92)     0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  conv2d_9 (Conv2D)              (None, 1, 1, 24)     2232        ['reshape[0][0]']
#
#  activation_9 (Activation)      (None, 1, 1, 24)     0           ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 1, 1, 92)     2300        ['activation_9[0][0]']
#
#  activation_10 (Activation)     (None, 1, 1, 92)     0           ['conv2d_10[0][0]']
#
#  multiply (Multiply)            (None, 28, 28, 92)   0           ['batch_normalization_18[0][0]',
#                                                                   'activation_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 26)   2392        ['multiply[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 28, 28, 32)  800         ['add_2[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 26)  104         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 32)  128         ['depthwise_conv2d_11[0][0]']
#  ormalization)
#
#  depthwise_conv2d_10 (Depthwise  (None, 28, 28, 26)  234         ['batch_normalization_19[0][0]']
#  Conv2D)
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 52)   1664        ['batch_normalization_21[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 26)  104         ['depthwise_conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 52)  208         ['conv2d_12[0][0]']
#  ormalization)
#
#  concatenate_7 (Concatenate)    (None, 28, 28, 52)   0           ['batch_normalization_19[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 52)   0           ['batch_normalization_22[0][0]',
#                                                                   'concatenate_7[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 78)   4056        ['add_3[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 78)  312         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 78)   0           ['batch_normalization_23[0][0]']
#
#  depthwise_conv2d_12 (Depthwise  (None, 28, 28, 78)  702         ['activation_11[0][0]']
#  Conv2D)
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 78)  312         ['depthwise_conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 28, 28, 78)   0           ['batch_normalization_24[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 28, 28, 156)  0           ['activation_11[0][0]',
#                                                                   'activation_12[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 156)         0           ['concatenate_8[0][0]']
#  obalAveragePooling2D)
#
#  reshape_1 (Reshape)            (None, 1, 1, 156)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  conv2d_14 (Conv2D)             (None, 1, 1, 40)     6280        ['reshape_1[0][0]']
#
#  activation_13 (Activation)     (None, 1, 1, 40)     0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 1, 1, 156)    6396        ['activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 1, 1, 156)    0           ['conv2d_15[0][0]']
#
#  multiply_1 (Multiply)          (None, 28, 28, 156)  0           ['concatenate_8[0][0]',
#                                                                   'activation_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 26)   4056        ['multiply_1[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 26)  104         ['conv2d_16[0][0]']
#  ormalization)
#
#  depthwise_conv2d_13 (Depthwise  (None, 28, 28, 26)  234         ['batch_normalization_25[0][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 28, 28, 26)  104         ['depthwise_conv2d_13[0][0]']
#  ormalization)
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 52)   0           ['batch_normalization_25[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  add_4 (Add)                    (None, 28, 28, 52)   0           ['add_3[0][0]',
#                                                                   'concatenate_9[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 156)  8112        ['add_4[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 28, 28, 156)  624        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 28, 28, 156)  0           ['batch_normalization_27[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (None, 28, 28, 156)  1404       ['activation_15[0][0]']
#  Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 28, 28, 156)  624        ['depthwise_conv2d_14[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 156)  0           ['batch_normalization_28[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 312)  0           ['activation_15[0][0]',
#                                                                   'activation_16[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 14, 14, 312)  2808       ['concatenate_10[0][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 312)  1248       ['depthwise_conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 52)   16224       ['batch_normalization_29[0][0]']
#
#  depthwise_conv2d_17 (Depthwise  (None, 14, 14, 52)  468         ['add_4[0][0]']
#  Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 52)  208         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 52)  208         ['depthwise_conv2d_17[0][0]']
#  ormalization)
#
#  depthwise_conv2d_16 (Depthwise  (None, 14, 14, 52)  468         ['batch_normalization_30[0][0]']
#  Conv2D)
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 104)  5408        ['batch_normalization_32[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 52)  208         ['depthwise_conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 104)  416        ['conv2d_19[0][0]']
#  ormalization)
#
#  concatenate_11 (Concatenate)   (None, 14, 14, 104)  0           ['batch_normalization_30[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  add_5 (Add)                    (None, 14, 14, 104)  0           ['batch_normalization_33[0][0]',
#                                                                   'concatenate_11[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 130)  13520       ['add_5[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 130)  520        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 14, 14, 130)  0           ['batch_normalization_34[0][0]']
#
#  depthwise_conv2d_18 (Depthwise  (None, 14, 14, 130)  1170       ['activation_17[0][0]']
#  Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 130)  520        ['depthwise_conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 14, 14, 130)  0           ['batch_normalization_35[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 14, 14, 260)  0           ['activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 52)   13520       ['concatenate_12[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 52)  208         ['conv2d_21[0][0]']
#  ormalization)
#
#  depthwise_conv2d_19 (Depthwise  (None, 14, 14, 52)  468         ['batch_normalization_36[0][0]']
#  Conv2D)
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 52)  208         ['depthwise_conv2d_19[0][0]']
#  ormalization)
#
#  concatenate_13 (Concatenate)   (None, 14, 14, 104)  0           ['batch_normalization_36[0][0]',
#                                                                   'batch_normalization_37[0][0]']
#
#  add_6 (Add)                    (None, 14, 14, 104)  0           ['add_5[0][0]',
#                                                                   'concatenate_13[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 120)  12480       ['add_6[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 120)  480        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 14, 14, 120)  0           ['batch_normalization_38[0][0]']
#
#  depthwise_conv2d_20 (Depthwise  (None, 14, 14, 120)  1080       ['activation_19[0][0]']
#  Conv2D)
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 120)  480        ['depthwise_conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 14, 14, 120)  0           ['batch_normalization_39[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 14, 14, 240)  0           ['activation_19[0][0]',
#                                                                   'activation_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 52)   12480       ['concatenate_14[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 52)  208         ['conv2d_23[0][0]']
#  ormalization)
#
#  depthwise_conv2d_21 (Depthwise  (None, 14, 14, 52)  468         ['batch_normalization_40[0][0]']
#  Conv2D)
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 52)  208         ['depthwise_conv2d_21[0][0]']
#  ormalization)
#
#  concatenate_15 (Concatenate)   (None, 14, 14, 104)  0           ['batch_normalization_40[0][0]',
#                                                                   'batch_normalization_41[0][0]']
#
#  add_7 (Add)                    (None, 14, 14, 104)  0           ['add_6[0][0]',
#                                                                   'concatenate_15[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 120)  12480       ['add_7[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 120)  480        ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 120)  0           ['batch_normalization_42[0][0]']
#
#  depthwise_conv2d_22 (Depthwise  (None, 14, 14, 120)  1080       ['activation_21[0][0]']
#  Conv2D)
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 120)  480        ['depthwise_conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 120)  0           ['batch_normalization_43[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 14, 14, 240)  0           ['activation_21[0][0]',
#                                                                   'activation_22[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 52)   12480       ['concatenate_16[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 52)  208         ['conv2d_25[0][0]']
#  ormalization)
#
#  depthwise_conv2d_23 (Depthwise  (None, 14, 14, 52)  468         ['batch_normalization_44[0][0]']
#  Conv2D)
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 52)  208         ['depthwise_conv2d_23[0][0]']
#  ormalization)
#
#  concatenate_17 (Concatenate)   (None, 14, 14, 104)  0           ['batch_normalization_44[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  add_8 (Add)                    (None, 14, 14, 104)  0           ['add_7[0][0]',
#                                                                   'concatenate_17[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 312)  32448       ['add_8[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 14, 14, 312)  1248       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 312)  0           ['batch_normalization_46[0][0]']
#
#  depthwise_conv2d_24 (Depthwise  (None, 14, 14, 312)  2808       ['activation_23[0][0]']
#  Conv2D)
#
#  batch_normalization_47 (BatchN  (None, 14, 14, 312)  1248       ['depthwise_conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 14, 14, 312)  0           ['batch_normalization_47[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 14, 14, 624)  0           ['activation_23[0][0]',
#                                                                   'activation_24[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 624)         0           ['concatenate_18[0][0]']
#  obalAveragePooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 1, 624)    0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  conv2d_27 (Conv2D)             (None, 1, 1, 156)    97500       ['reshape_2[0][0]']
#
#  activation_25 (Activation)     (None, 1, 1, 156)    0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 1, 1, 624)    97968       ['activation_25[0][0]']
#
#  activation_26 (Activation)     (None, 1, 1, 624)    0           ['conv2d_28[0][0]']
#
#  multiply_2 (Multiply)          (None, 14, 14, 624)  0           ['concatenate_18[0][0]',
#                                                                   'activation_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 72)   44928       ['multiply_2[0][0]']
#
#  depthwise_conv2d_26 (Depthwise  (None, 14, 14, 104)  936        ['add_8[0][0]']
#  Conv2D)
#
#  batch_normalization_48 (BatchN  (None, 14, 14, 72)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 14, 14, 104)  416        ['depthwise_conv2d_26[0][0]']
#  ormalization)
#
#  depthwise_conv2d_25 (Depthwise  (None, 14, 14, 72)  648         ['batch_normalization_48[0][0]']
#  Conv2D)
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 144)  14976       ['batch_normalization_50[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 14, 14, 72)  288         ['depthwise_conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 14, 14, 144)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  concatenate_19 (Concatenate)   (None, 14, 14, 144)  0           ['batch_normalization_48[0][0]',
#                                                                   'batch_normalization_49[0][0]']
#
#  add_9 (Add)                    (None, 14, 14, 144)  0           ['batch_normalization_51[0][0]',
#                                                                   'concatenate_19[0][0]']
# ...
#  batch_normalization_67 (BatchN  (None, 7, 7, 624)   2496        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 7, 7, 624)    0           ['batch_normalization_67[0][0]']
#
#  depthwise_conv2d_35 (Depthwise  (None, 7, 7, 624)   5616        ['activation_37[0][0]']
#  Conv2D)
#
#  batch_normalization_68 (BatchN  (None, 7, 7, 624)   2496        ['depthwise_conv2d_35[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 7, 7, 624)    0           ['batch_normalization_68[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 7, 7, 1248)   0           ['activation_37[0][0]',
#                                                                   'activation_38[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 1248)        0           ['concatenate_26[0][0]']
#  obalAveragePooling2D)
#
#  reshape_5 (Reshape)            (None, 1, 1, 1248)   0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  conv2d_43 (Conv2D)             (None, 1, 1, 312)    389688      ['reshape_5[0][0]']
#
#  activation_39 (Activation)     (None, 1, 1, 312)    0           ['conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 1, 1, 1248)   390624      ['activation_39[0][0]']
#
#  activation_40 (Activation)     (None, 1, 1, 1248)   0           ['conv2d_44[0][0]']
#
#  multiply_5 (Multiply)          (None, 7, 7, 1248)   0           ['concatenate_26[0][0]',
#                                                                   'activation_40[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 104)    129792      ['multiply_5[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 7, 7, 104)   416         ['conv2d_45[0][0]']
#  ormalization)
#
#  depthwise_conv2d_36 (Depthwise  (None, 7, 7, 104)   936         ['batch_normalization_69[0][0]']
#  Conv2D)
#
#  batch_normalization_70 (BatchN  (None, 7, 7, 104)   416         ['depthwise_conv2d_36[0][0]']
#  ormalization)
#
#  concatenate_27 (Concatenate)   (None, 7, 7, 208)    0           ['batch_normalization_69[0][0]',
#                                                                   'batch_normalization_70[0][0]']
#
#  add_13 (Add)                   (None, 7, 7, 208)    0           ['add_12[0][0]',
#                                                                   'concatenate_27[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 624)    129792      ['add_13[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 7, 7, 624)   2496        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 7, 7, 624)    0           ['batch_normalization_71[0][0]']
#
#  depthwise_conv2d_37 (Depthwise  (None, 7, 7, 624)   5616        ['activation_41[0][0]']
#  Conv2D)
#
#  batch_normalization_72 (BatchN  (None, 7, 7, 624)   2496        ['depthwise_conv2d_37[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 7, 7, 624)    0           ['batch_normalization_72[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 7, 7, 1248)   0           ['activation_41[0][0]',
#                                                                   'activation_42[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 104)    129792      ['concatenate_28[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 7, 7, 104)   416         ['conv2d_47[0][0]']
#  ormalization)
#
#  depthwise_conv2d_38 (Depthwise  (None, 7, 7, 104)   936         ['batch_normalization_73[0][0]']
#  Conv2D)
#
#  batch_normalization_74 (BatchN  (None, 7, 7, 104)   416         ['depthwise_conv2d_38[0][0]']
#  ormalization)
#
#  concatenate_29 (Concatenate)   (None, 7, 7, 208)    0           ['batch_normalization_73[0][0]',
#                                                                   'batch_normalization_74[0][0]']
#
#  add_14 (Add)                   (None, 7, 7, 208)    0           ['add_13[0][0]',
#                                                                   'concatenate_29[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 332)    69056       ['add_14[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 7, 7, 332)   1328        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 7, 7, 332)    0           ['batch_normalization_75[0][0]']
#
#  depthwise_conv2d_39 (Depthwise  (None, 7, 7, 332)   2988        ['activation_43[0][0]']
#  Conv2D)
#
#  batch_normalization_76 (BatchN  (None, 7, 7, 332)   1328        ['depthwise_conv2d_39[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 7, 7, 332)    0           ['batch_normalization_76[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 7, 7, 664)    0           ['activation_43[0][0]',
#                                                                   'activation_44[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 664)         0           ['concatenate_30[0][0]']
#  obalAveragePooling2D)
#
#  reshape_6 (Reshape)            (None, 1, 1, 664)    0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  conv2d_49 (Conv2D)             (None, 1, 1, 168)    111720      ['reshape_6[0][0]']
#
#  activation_45 (Activation)     (None, 1, 1, 168)    0           ['conv2d_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 1, 1, 664)    112216      ['activation_45[0][0]']
#
#  activation_46 (Activation)     (None, 1, 1, 664)    0           ['conv2d_50[0][0]']
#
#  multiply_6 (Multiply)          (None, 7, 7, 664)    0           ['concatenate_30[0][0]',
#                                                                   'activation_46[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 104)    69056       ['multiply_6[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 7, 7, 104)   416         ['conv2d_51[0][0]']
#  ormalization)
#
#  depthwise_conv2d_40 (Depthwise  (None, 7, 7, 104)   936         ['batch_normalization_77[0][0]']
#  Conv2D)
#
#  batch_normalization_78 (BatchN  (None, 7, 7, 104)   416         ['depthwise_conv2d_40[0][0]']
#  ormalization)
#
#  concatenate_31 (Concatenate)   (None, 7, 7, 208)    0           ['batch_normalization_77[0][0]',
#                                                                   'batch_normalization_78[0][0]']
#
#  add_15 (Add)                   (None, 7, 7, 208)    0           ['add_14[0][0]',
#                                                                   'concatenate_31[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 664)    138112      ['add_15[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 7, 7, 664)   2656        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 7, 7, 664)    0           ['batch_normalization_79[0][0]']
#
#  GDC_dw (DepthwiseConv2D)       (None, 1, 1, 664)    32536       ['activation_47[0][0]']
#
#  GDC_batchnorm (BatchNormalizat  (None, 1, 1, 664)   2656        ['GDC_dw[0][0]']
#  ion)
#
#  GDC_conv (Conv2D)              (None, 1, 1, 512)    339968      ['GDC_batchnorm[0][0]']
#
#  GDC_flatten (Flatten)          (None, 512)          0           ['GDC_conv[0][0]']
#
#  pre_embedding (BatchNormalizat  (None, 512)         2048        ['GDC_flatten[0][0]']
#  ion)
#
#  embedding (Activation)         (None, 512)          0           ['pre_embedding[0][0]']
#
# ==================================================================================================
# Total params: 4,078,224
# Trainable params: 4,049,672
# Non-trainable params: 28,552
# __________________________________________________________________________________________________

# %%
i = 0
succ = 0
buffer = []
for line in open(facescrub_lst, 'r'):
    if i % 1000 == 0:
        print("writing fs", i, succ)
    i += 1
    image_path = line.strip()
    _path = image_path.split('/')
    a, b = _path[-2], _path[-1]
    out_dir = os.path.join(facescrub_out, a)
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    image_path = os.path.join(facescrub_root, image_path)
    print(image_path)
    img = read_img(image_path)
    if img is None:
        print('read error:', image_path)
        continue
    out_path = os.path.join(out_dir, b + "_%s.bin" % (algo))
    item = (img, out_path)
    buffer.append(item)
    if len(buffer) == batch_size:
        get_and_write(buffer, model)
        buffer = []
    succ += 1
if len(buffer) > 0:
    get_and_write(buffer, model)
    buffer = []
print('fs stat', i, succ)

i = 0
succ = 0
buffer = []
for line in open(megaface_lst, 'r'):
    if i % 1000 == 0:
        print("writing mf", i, succ)
    i += 1
    image_path = line.strip()
    _path = image_path.split('/')
    a1, a2, b = _path[-3], _path[-2], _path[-1]
    out_dir = os.path.join(megaface_out, a1, a2)
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
        #continue
    #print(landmark)
    image_path = os.path.join(megaface_root, image_path)
    img = read_img(image_path)
    if img is None:
        print('read error:', image_path)
        continue
    out_path = os.path.join(out_dir, b + "_%s.bin" % (algo))
    item = (img, out_path)
    buffer.append(item)
    if len(buffer) == batch_size:
        get_and_write(buffer, model)
        buffer = []
    succ += 1
if len(buffer) > 0:
    get_and_write(buffer, model)
    buffer = []
print('mf stat', i, succ)
# Out:
# writing fs 0 0
# data/facescrub_images/Christian_Bale/Christian_Bale_11936.png
# <class 'numpy.ndarray'>
# data/facescrub_images/Julie_Bowen/Julie_Bowen_9303.png
# <class 'numpy.ndarray'>
# data/facescrub_images/John_Malkovich/John_Malkovich_32959.png
# <class 'numpy.ndarray'>
# data/facescrub_images/Fran_Drescher/Fran_Drescher_22994.png
# <class 'numpy.ndarray'>
# data/facescrub_images/James_Remar/James_Remar_27141.png
# <class 'numpy.ndarray'>
# data/facescrub_images/Christopher_Reeve/Christopher_Reeve_12711.png
# <class 'numpy.ndarray'>
# data/facescrub_images/Oliver_Platt/Oliver_Platt_45702.png
# <class 'numpy.ndarray'>
# data/facescrub_images/Chris_Evans/Chris_Evans_11010.png
# <class 'numpy.ndarray'>
